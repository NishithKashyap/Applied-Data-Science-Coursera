# %% [markdown]
# # Assignment 4
#
# Before working on this assignment please read these instructions fully. In the submission area, you will notice that you can click the link to **Preview the Grading** for each step of the assignment. This is the criteria that will be used for peer grading. Please familiarize yourself with the criteria before beginning the assignment.
#
# This assignment requires that you to find **at least** two datasets on the web which are related, and that you visualize these datasets to answer a question with the broad topic of **sports or athletics** (see below) for the region of **Ann Arbor, Michigan, United States**, or **United States** more broadly.
#
# You can merge these datasets with data from different regions if you like! For instance, you might want to compare **Ann Arbor, Michigan, United States** to Ann Arbor, USA. In that case at least one source file must be about **Ann Arbor, Michigan, United States**.
#
# You are welcome to choose datasets at your discretion, but keep in mind **they will be shared with your peers**, so choose appropriate datasets. Sensitive, confidential, illicit, and proprietary materials are not good choices for datasets for this assignment. You are welcome to upload datasets of your own as well, and link to them using a third party repository such as github, bitbucket, pastebin, etc. Please be aware of the Coursera terms of service with respect to intellectual property.
#
# Also, you are welcome to preserve data in its original language, but for the purposes of grading you should provide english translations. You are welcome to provide multiple visuals in different languages if you would like!
#
# As this assignment is for the whole course, you must incorporate principles discussed in the first week, such as having as high data-ink ratio (Tufte) and aligning with Cairo’s principles of truth, beauty, function, and insight.
#
# Here are the assignment instructions:
#
#  * State the region and the domain category that your data sets are about (e.g., **Ann Arbor, Michigan, United States** and **sports or athletics**).
#  * You must state a question about the domain category and region that you identified as being interesting.
#  * You must provide at least two links to available datasets. These could be links to files such as CSV or Excel files, or links to websites which might have data in tabular form, such as Wikipedia pages.
#  * You must upload an image which addresses the research question you stated. In addition to addressing the question, this visual should follow Cairo's principles of truthfulness, functionality, beauty, and insightfulness.
#  * You must contribute a short (1-2 paragraph) written justification of how your visualization addresses your stated research question.
#
# What do we mean by **sports or athletics**?  For this category we are interested in sporting events or athletics broadly, please feel free to creatively interpret the category when building your research question!
#
# ## Tips
# * Wikipedia is an excellent source of data, and I strongly encourage you to explore it for new data sources.
# * Many governments run open data initiatives at the city, region, and country levels, and these are wonderful resources for localized data sources.
# * Several international agencies, such as the [United Nations](http://data.un.org/), the [World Bank](http://data.worldbank.org/), the [Global Open Data Index](http://index.okfn.org/place/) are other great places to look for data.
# * This assignment requires you to convert and clean datafiles. Check out the discussion forums for tips on how to do this from various sources, and share your successes with your fellow students!
#
# ## Example
# Looking for an example? Here's what our course assistant put together for the **Ann Arbor, MI, USA** area using **sports and athletics** as the topic. [Example Solution File](./readonly/Assignment4_example.pdf)
#
# https://data.gov.sg/dataset/credit-and-charge-card-statistics?view_id=a2daba98-5c68-422c-b101-626d74c93e24&resource_id=aae7f304-f003-4c82-83e2-c0c05590f061

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib notebook

# %%
df_annual = pd.read_csv(r'C:\Users\User\Desktop\credit-and-charge-card-statistics-annual.csv')
df_annual
# Out:
#     year  cards_main  cards_supplementary  total_billings  rollover_balance  \
# 0   1989      418634               213103          1971.4             178.1
# 1   1990      534346               276362          2715.6             294.9
# 2   1991      683620               326186          3381.6             433.0
# 3   1992      716196               346415          3944.8             537.8
# 4   1993      838029               417613          4605.9             622.4
# 5   1994      964359               485665          5475.6             705.3
# 6   1995     1059408               536408          6152.8             825.5
# 7   1996     1117131               577394          6985.9             893.6
# 8   1997     1241104               626354          7915.1            1035.3
# 9   1998     1369089               681508          7689.1            1113.4
# 10  1999     1504531               725745          8941.9            1370.3
# ...

# %%
'''import warnings
warnings.filterwarnings("ignore")

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
df_month.iloc[:,1:] = sc.fit_transform(df_month.iloc[:,1:])

df_month

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
df_annual.iloc[:,1:] = sc.fit_transform(df_annual.iloc[:,1:])

df_annual'''
# Out:
# 'import warnings\nwarnings.filterwarnings("ignore")\n\nfrom sklearn.preprocessing import StandardScaler\nsc = StandardScaler()\ndf_month.iloc[:,1:] = sc.fit_transform(df_month.iloc[:,1:])\n\ndf_month\n\nfrom sklearn.preprocessing import StandardScaler\nsc = StandardScaler()\ndf_annual.iloc[:,1:] = sc.fit_transform(df_annual.iloc[:,1:])\n\ndf_annual'

# %%
type(df_annual)
# Out:
# pandas.core.frame.DataFrame

# %%
df_month = pd.read_csv(r'C:\Users\User\Desktop\credit-and-charge-card-statistics-monthly.csv')
df_month
# Out:
#        month  cards_main  cards_supplementary  total_billings  \
# 0    1991-01      543435               276974           270.4
# 1    1991-02      548887               281988           231.9
# 2    1991-03      561003               281872           229.5
# 3    1991-04      574342               286936           262.3
# 4    1991-05      589765               292965           277.3
# ..       ...         ...                  ...             ...
# 291  2015-04     8187404              1543020          3756.4
# 292  2015-05     8190208              1531560          3892.2
# 293  2015-06     8175901              1525898          3980.4
# 294  2015-07     8143294              1518198          3917.8
# 295  2015-08     8122345              1512412          3795.8
#
#      rollover_balance
# 0               297.1
# 1               320.8
# 2               311.2
# 3               320.5
# 4               324.6
# ..                ...
# 291            5449.9
# 292            5425.7
# ...

# %%
df_annual.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 7 columns):
# year                     26 non-null int64
# cards_main               26 non-null int64
# cards_supplementary      26 non-null int64
# total_billings           26 non-null float64
# rollover_balance         26 non-null float64
# bad_debts_written_off    26 non-null float64
# charge_off_rates         26 non-null float64
# dtypes: float64(4), int64(3)
# memory usage: 1.5 KB

# %%
df_month.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 296 entries, 0 to 295
# Data columns (total 5 columns):
# month                  296 non-null object
# cards_main             296 non-null int64
# cards_supplementary    296 non-null int64
# total_billings         296 non-null float64
# rollover_balance       296 non-null float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 11.7+ KB

# %% [markdown]
# ### Remove the unwanted columns from annual dataset to match with monthly data

# %%
df_annual = df_annual[['year','cards_main','cards_supplementary','total_billings','rollover_balance']]
df_annual.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 5 columns):
# year                   26 non-null int64
# cards_main             26 non-null int64
# cards_supplementary    26 non-null int64
# total_billings         26 non-null float64
# rollover_balance       26 non-null float64
# dtypes: float64(2), int64(3)
# memory usage: 1.1 KB

# %% [markdown]
# ### Convert monthly data to yearly in monthly dataset for comparision

# %%
df_month['year'], df_month['month_of_year'] = zip(*df_month['month'].apply(lambda x: (x[:4],x[5:])))

# %%
df_month
# Out:
#        month  cards_main  cards_supplementary  total_billings  \
# 0    1991-01      543435               276974           270.4
# 1    1991-02      548887               281988           231.9
# 2    1991-03      561003               281872           229.5
# 3    1991-04      574342               286936           262.3
# 4    1991-05      589765               292965           277.3
# ..       ...         ...                  ...             ...
# 291  2015-04     8187404              1543020          3756.4
# 292  2015-05     8190208              1531560          3892.2
# 293  2015-06     8175901              1525898          3980.4
# 294  2015-07     8143294              1518198          3917.8
# 295  2015-08     8122345              1512412          3795.8
#
#      rollover_balance  year month_of_year
# 0               297.1  1991            01
# 1               320.8  1991            02
# 2               311.2  1991            03
# 3               320.5  1991            04
# ...

# %% [markdown]
# #### Drop unwanted columns

# %%
df_month = df_month[['year','cards_main','cards_supplementary','total_billings','rollover_balance']]
df_month
# Out:
#      year  cards_main  cards_supplementary  total_billings  rollover_balance
# 0    1991      543435               276974           270.4             297.1
# 1    1991      548887               281988           231.9             320.8
# 2    1991      561003               281872           229.5             311.2
# 3    1991      574342               286936           262.3             320.5
# 4    1991      589765               292965           277.3             324.6
# ..    ...         ...                  ...             ...               ...
# 291  2015     8187404              1543020          3756.4            5449.9
# 292  2015     8190208              1531560          3892.2            5425.7
# 293  2015     8175901              1525898          3980.4            5401.8
# 294  2015     8143294              1518198          3917.8            5244.5
# 295  2015     8122345              1512412          3795.8            5271.4
#
# [296 rows x 5 columns]

# %%
years = df_month['year'].unique().tolist()

# %%
years = years[:-1]

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
'''year = [i for i in range(1989,2015)]
years = df_month['year'].unique().tolist()

fig = plt.figure(figsize=(20,10))
ax1 = fig.add_subplot(111)
plt.xticks(year)
plt.yticks(ticks=None)
plt.bar(df_annual['year'], df_annual['cards_main'], width = 0.3, color='b')
#plt.bar(df_annual['year'], df_annual['cards_supplementary'], width = 0.3, color='r')

ax2 = fig.add_subplot(111, sharex=ax1, frameon=False)
ax2.plot(years, average['cards_main'], '-o', color = 'm', alpha = 0.75)
ax2.yaxis.tick_right()
ax2.yaxis.set_label_position("right")
plt.tight_layout()'''
# Out:
# 'year = [i for i in range(1989,2015)]\nyears = df_month[\'year\'].unique().tolist()\n\nfig = plt.figure(figsize=(20,10))\nax1 = fig.add_subplot(111)\nplt.xticks(year)\nplt.yticks(ticks=None)\nplt.bar(df_annual[\'year\'], df_annual[\'cards_main\'], width = 0.3, color=\'b\')\n#plt.bar(df_annual[\'year\'], df_annual[\'cards_supplementary\'], width = 0.3, color=\'r\')\n\nax2 = fig.add_subplot(111, sharex=ax1, frameon=False)\nax2.plot(years, average[\'cards_main\'], \'-o\', color = \'m\', alpha = 0.75)\nax2.yaxis.tick_right()\nax2.yaxis.set_label_position("right")\nplt.tight_layout()'

# %% [markdown]
# ### Average of the attributes every year is found out

# %%
average = df_month.groupby(['year']).mean()
average
# Out:
#         cards_main  cards_supplementary  total_billings  rollover_balance
# year
# 1991  6.130371e+05         3.012739e+05      281.800000        355.566667
# 1992  6.927542e+05         3.320745e+05      328.725000        480.666667
# 1993  7.735609e+05         3.757868e+05      383.833333        565.458333
# 1994  9.090158e+05         4.522745e+05      456.300000        662.983333
# 1995  1.015453e+06         5.122942e+05      512.733333        747.650000
# 1996  1.082146e+06         5.560996e+05      582.158333        857.966667
# 1997  1.184628e+06         6.056161e+05      659.591667        928.858333
# 1998  1.304277e+06         6.509938e+05      640.758333       1070.758333
# 1999  1.423111e+06         7.056620e+05      745.158333       1236.500000
# 2000  1.587899e+06         7.462924e+05      878.000000       1528.291667
# 2001  1.825184e+06         8.028765e+05      919.775000       1844.925000
# 2002  2.090524e+06         8.872666e+05      991.775000       2210.708333
# ...

# %% [markdown]
# ### Comparision of cards_main and cards_supplementary data as provided by the two datasets (annual and monthly)
#
# In the monthly dataset, year-wise average of the above mentioned attributes is found out for comparision

# %%
width = .65
avg = df_annual['cards_main'].mean()

df_annual[['cards_main','cards_supplementary']].plot(kind='bar',width = width)
average['cards_main'].plot(secondary_y=True)
average['cards_supplementary'].plot(secondary_y=True)
ax = plt.gca()
plt.rcParams["figure.figsize"] = [25,15]
plt.show()
